# %% [markdown]
# # Group analysis for the imagmove task
#
# * The EEG data of 16 participants has been preprocessed and will be used here.
#
# * We will show the event-related desynchronization (ERD) and event-related synchronization (ERS) of imaging left and right hand movements.

# %% [markdown]
# ## Change to the folder where the processed data stored

# %%
processed_data_folder='Z:/psy-interbrain/Shared/Jan/CIBA120_data/processed_data/'

# %% [markdown]
# ## Import packages and define variables

# %%
import mne
import numpy as np
from mne.time_frequency import tfr_multitaper

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

Ids=[9,10,12,13,14,15,16,26,27,28,29,30,31,32,33,34]
freqs = np.arange(8, 16, 1)
baseline=(-2, 0)
state='imag'
conditions=['rest','imagine left','imagine right']
channels=['C3','Cz','C4']

# %% [markdown]
# ## Load the epoch data and calculate the time-frequency representation

# %%
tfr_all=dict()
for id in Ids:
    tfrs=dict()
    epochs=mne.read_epochs(processed_data_folder+'imagmove_%03d-less_channels-epo.fif'%(id)).pick_channels(channels)
    tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=freqs, use_fft=True,return_itc=False, average=False)
    tfr.crop(-2,10).apply_baseline(baseline, mode="percent")
    for condition in conditions:
           tfrs[condition]=tfr[condition].average()
    tfr_all[id]=tfrs
# Out:
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_009-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_010-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s finished
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_012-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_013-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_014-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_015-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_016-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_026-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_027-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_028-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_029-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_030-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_031-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_032-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_033-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Reading C:\Users\subtl\OneDrive\Area\Teaching\CIBA120-2022\CIBA120-2022-Analyzing EEG\processed_data\imagmove_034-less_channels-epo.fif ...
#     Found the data of interest:
#         t =   -4000.00 ...   12000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s finished

# %% [markdown]
# ## Calculate the grand average for all conditions

# %%
GA_tfr=dict()
for cond in conditions:
    GA_tfr[cond]=mne.grand_average([sub[cond] for sub in tfr_all.values()])
    GA_tfr[cond].comment=cond
# Out:
# Identifying common channels ...
# Identifying common channels ...
# Identifying common channels ...

# %% [markdown]
# ## Plot the grand average time-frequency responses

# %%
fig, axs = plt.subplots(3, 3,sharex=True, sharey=True,figsize=(14,12))
for i,condition in enumerate(conditions):   
    for j,channel in enumerate(channels):
        GA_tfr[condition].plot([channel],vmin=-0.5, vmax=1,axes=axs[i,j],show=False)
        axs[i,j].set_title(condition+'_'+channel)
fig.show()
# Out:
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# C:\Users\subtl\AppData\Local\Temp\ipykernel_7748\4185883785.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## plot the grand averge of ERS/ERD

# %%
df_list=list()
for id in Ids:
    for condition in conditions:
        df=tfr_all[id][condition].to_data_frame(time_format=None, long_format=True)
        df['condition']=condition
        df['id']=id
        df=df.rename(columns={'value':'ERDS'})
        df_list.append(df)        
df_all=pd.concat(df_list)    


df_all_freq_avg=df_all.groupby(['time','channel','id','condition'])['ERDS'].mean().reset_index()
df_all_freq_avg['channel'] = df_all_freq_avg['channel'].cat.reorder_categories(('C3', 'Cz', 'C4'), ordered=True)
plt.figure(figsize=(16,6))
g = sns.FacetGrid(df_all_freq_avg, row=None, col='condition')
g.map(sns.lineplot, 'time', 'ERDS', 'channel', n_boot=10)
axline_kw = dict(color='black', linestyle='dashed', linewidth=0.5, alpha=0.5)
g.map(plt.axhline, y=0, **axline_kw)
g.map(plt.axvline, x=0, **axline_kw)
g.set(ylim=(None, 1.5))
g.set_axis_labels("Time (s)", "ERDS (%)")
g.set_titles(col_template="{col_name}", row_template="{row_name}")
g.add_legend()
# Out:
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# Converting "channel" to "category"...
# Converting "ch_type" to "category"...
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %% [markdown]
# ## plot ERS/ERD for each participants

# %%
plt.figure(figsize=(16,16))
g = sns.FacetGrid(df_all, col="id", col_wrap=4, height=2, )
g.map(sns.pointplot, "channel", "ERDS",'condition',palette=sns.color_palette("pastel"))
g.map(plt.axhline, y=0, **axline_kw)
g.set_axis_labels("Channels (s)", "ERDS (%)")
g.add_legend()
# Out:
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:717: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %% [markdown]
# ## Compare the ERS/ERD responses during imaging left and right hand move

# %%
df_TW=df_all.query("time > 0.0 & time < 5.0 & condition !='rest' ")
df_TW=df_TW.groupby(['channel','id','condition'])['ERDS'].mean().reset_index()
df_TW['channel'] = df_TW['channel'].cat.reorder_categories(('C3', 'Cz', 'C4'), ordered=True)
df_TW=df_TW[df_TW['channel']!='Cz']
df_TW['channel'].cat.remove_unused_categories(inplace=True)
plt.figure()
sns.boxplot(x="condition", y="ERDS", hue="channel", data=df_TW, palette="Set3")
# Out:
# C:\Users\subtl\AppData\Local\Temp\ipykernel_7748\2670511857.py:5: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_TW['channel'].cat.remove_unused_categories(inplace=True)
# <AxesSubplot: xlabel='condition', ylabel='ERDS'>

# %% [markdown]
# ## Statistical analysis of ERS/ERD responses during imaging left and right hand move

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.graphics.factorplots import interaction_plot
import matplotlib.pyplot as plt
fig = interaction_plot(x=df_TW['condition'], trace=df_TW['channel'], response=df_TW['ERDS'])
plt.show()

#perform two-way ANOVA
model = ols('ERDS ~ C(channel) + C(condition) + C(channel):C(condition)', data=df_TW).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\statsmodels\graphics\factorplots.py:131: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, (values, group) in enumerate(plot_data.groupby(['trace'])):
#                            sum_sq    df         F    PR(>F)
# C(channel)               0.019559   1.0  0.265900  0.607990
# C(condition)             0.013565   1.0  0.184411  0.669148
# C(channel):C(condition)  0.313210   1.0  4.257978  0.043400
# Residual                 4.413507  60.0       NaN       NaN

# %% [markdown]
# ## Save the ERS/ERD results to CSV

# %%
df_TW.to_csv('ImagMove.csv')
