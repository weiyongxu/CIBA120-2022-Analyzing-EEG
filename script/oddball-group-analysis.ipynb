# %% [markdown]
# # Group analysis for the oddball task
#
# * The EEG data of 15 participants has been preprocessed and will be used here.
#
# * We will fisrt show the grand average of standard and deviant responses in both attend and ignore conditions.

# %% [markdown]
# ## Change to the folder where the processed data stored

# %%
processed_data_folder='Z:/psy-interbrain/Shared/Jan/CIBA120_data/processed_data/'

# %% [markdown]
# ## Import packages and define variables

# %%
import mne
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# A total of 15 participatns are included here
Ids=[9,11,12,13,14,15,26,27,28,29,30,31,32,33,34]
states=['attend','ignore']

# %% [markdown]
# ## Load the epoch data and make evoked data

# %%
evoked_all=dict()
for id in Ids:
    evoked=dict()
    for state in states: 
        epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))        
        for condition in epochs.event_id.keys():
            evoked[condition]=epochs[condition].average()            
        evoked_all[id]=evoked
# Out:
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba009_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba009_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba011_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba011_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba012_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 196 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba012_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 194 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba013_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba013_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# 202 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba014_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 184 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba014_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 194 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba015_ob_attend-less_channels-epo.fif ...
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba015_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba026_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba026_ob_ignore-less_channels-epo.fif ...
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 188 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba027_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba027_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba028_ob_attend-less_channels-epo.fif ...
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba028_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba029_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba029_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 196 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba030_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 196 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba030_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 196 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba031_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba031_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 196 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba032_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba032_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba033_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba033_ob_ignore-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 198 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba034_ob_attend-less_channels-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading Z:\psy-interbrain\Shared\Jan\CIBA120_data\processed_data\ciba034_ob_ignore-less_channels-epo.fif ...
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
#     Found the data of interest:
#         t =    -100.00 ...     450.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))
# C:\Users\subtl\AppData\Local\Temp\ipykernel_14636\173364361.py:5: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epochs=mne.read_epochs(processed_data_folder+'ciba%03d_ob_%s-less_channels-epo.fif'%(id,state))

# %% [markdown]
# ## Calculate the grand average for all conditions

# %%
GA_evk=dict()
for cond in evoked.keys():
    GA_evk[cond]=mne.grand_average([sub[cond] for sub in evoked_all.values()])
    GA_evk[cond].comment=cond
# Out:
# Identifying common channels ...
# Identifying common channels ...
# Identifying common channels ...
# Identifying common channels ...

# %% [markdown]
# ## Calculate the difference responses between std and dev conditions

# %%
diff_attend=mne.combine_evoked([GA_evk['attend/deviant'],GA_evk['attend/standard'],], weights=[1,-1])
diff_ignore=mne.combine_evoked([GA_evk['ignore/deviant'],GA_evk['ignore/standard'],], weights=[1,-1])

# %% [markdown]
# ## Visualize the Grand Average responses

# %%
mne.viz.plot_compare_evokeds(GA_evk,picks=['Cz'])
mne.viz.plot_compare_evokeds([GA_evk['attend/standard'],GA_evk['attend/deviant'],diff_attend],picks=['Cz'],linestyles=['solid','solid','dotted'])
mne.viz.plot_compare_evokeds([GA_evk['ignore/standard'],GA_evk['ignore/deviant'],diff_ignore],picks=['Cz'],linestyles=['solid','solid','dotted'])        
mne.viz.plot_compare_evokeds([diff_attend,diff_ignore],picks=['Cz'],linestyles=['solid','solid'])
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %% [markdown]
# ## Extract the P3 component amplitude for attened and ignore conditions

# %%
P3_list=list()
ROI_chs=['Cz']
P3_TW=[0.24,0.28]
for id in Ids:
    P3=dict()
    attend_P3_diff=mne.combine_evoked([evoked_all[id]['attend/deviant'],evoked_all[id]['attend/standard'],], weights=[1,-1])
    ignore_P3_diff=mne.combine_evoked([evoked_all[id]['ignore/deviant'],evoked_all[id]['ignore/standard'],], weights=[1,-1])    
    P3['id']=id
    P3['attend_P3']=attend_P3_diff.crop(P3_TW[0],P3_TW[1]).pick_channels(ROI_chs).to_data_frame(index=None)[ROI_chs].mean().tolist()[0]
    P3['ignore_P3']=ignore_P3_diff.crop(P3_TW[0],P3_TW[1]).pick_channels(ROI_chs).to_data_frame(index=None)[ROI_chs].mean().tolist()[0]
    P3_list.append(P3)

# %% [markdown]
# ## Compare the P3 responses in attened and ignore conditions

# %%
df=pd.DataFrame(P3_list)
plt.figure()       
sns.barplot(df[['attend_P3','ignore_P3']])
sns.swarmplot(df[['attend_P3','ignore_P3']],palette='dark:black')
# Out:
# C:\Users\subtl\mne-python\1.2.0_0\lib\site-packages\seaborn\categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# <AxesSubplot: >

# %% [markdown]
# ## Statistical analysis of P3 between attend and ignore conditions

# %%
print(stats.ttest_rel(df['attend_P3'], df['ignore_P3']))
# Out:
# Ttest_relResult(statistic=4.107689072179969, pvalue=0.0010660071400458559)

# %% [markdown]
# ## Save the P3 results to CSV

# %%
df.to_csv('P3.csv')
